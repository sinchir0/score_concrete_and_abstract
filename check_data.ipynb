# %%
import pandas as pd
data = pd.read_csv("scored_text.csv")

# %%
data
# Out:
#                                               org_text          use_word  \
# 0    ＊＊＊の町というのはちいちゃくって、城壁がこう町全体をぐるっと回ってて、それが城壁の上を歩い...  ['それ', '上', '町']
# 1                                       １時間かからないぐらいだね。                []
# 2                                              ４、５０分で。             ['分']
# 3                                                そうそう。                []
# 4            ほいでさあ、ずっと歩いていたんだけど、そうすと上から、なんか町の中が見れるじゃん。        ['上', '町']
# ..                                                 ...               ...
# 822                                              そうだね。                []
# 823                                     これちょっとすてきに撮れた。            ['これ']
# 824                           なんかこれシャッターチャンスがさ、逃すんだよね。   ['これ', 'シャッター']
# 825                                           遅いもんでさあ。                []
# 826                                               反応が。                []
#
#      concrete_score
# 0            376.50
# 1               NaN
# 2            391.00
# 3               NaN
# 4            430.75
# ..              ...
# 822             NaN
# 823          281.50
# 824          414.50
# 825             NaN
# 826             NaN
#
# [827 rows x 3 columns]

# %%
data = data[data["concrete_score"].notnull()].reset_index(drop=True)

# %%
import ast
data["use_word_num"] = data["use_word"].apply(lambda x : len(ast.literal_eval(x)))
data["use_word_num"].mean()
# Out:
# 1.3977695167286246

# %%
data.shape
# Out:
# (827, 4)

# %% [markdown]
# ### 具体度が高い文章10件、推論なし

# %%
data.sort_values("concrete_score", ascending=False).head(10)
# Out:
#                                               org_text          use_word  \
# 341                      それでたっぷりミルクを入れてミルク、必ずミルクティーでー。           ['ミルク']
# 313                                        あとトマトも出るんだ。           ['トマト']
# 227                                  ３つベッドが、３つベッドがあって。           ['ベッド']
# 253                                 ベッドとブレックファストがついてる。           ['ベッド']
# 603                                             ジャケット。         ['ジャケット']
# 405                                          ジャケットポテト。  ['ジャケット', 'ポテト']
# 585                                        冷えたポテトだもんね。           ['ポテト']
# 392  はーとか思って、なんかさあ、ジャケッツってさあ、ジャケットポテ、普通は、ＤとかＣに聞いたら、...  ['ジャケット', 'ポテト']
# 403                                         あたしはジャケット。         ['ジャケット']
# 433                               あー、さめたポテトはね。いけてないねー。           ['ポテト']
#
#      concrete_score  use_word_num
# 341           654.0             1
# 313           636.0             1
# 227           635.0             1
# 253           635.0             1
# 603           623.0             1
# 405           623.0             2
# 585           623.0             1
# 392           623.0             2
# 403           623.0             1
# 433           623.0             1

# %% [markdown]
# ### 具体度が低い文章10件、推論なし

# %%
data.sort_values("concrete_score", ascending=True).head(10)
# Out:
#                                               org_text use_word  \
# 186                                   どこまで行くって言えばよかった。   ['どこ']
# 264                                       私どこを見てるんだろう。   ['どこ']
# 119                                           どこなんだろう。   ['どこ']
# 51   そういうときに調子よくさあ、大丈夫、大丈夫みたいな感じでね、ＯＫとかって、＊じゃあと＊でーと...  ['大丈夫']
# 210                       だからその前の日のジャケッツであたしは懲りているわけよ。    ['前']
# 146  ほいでさあ、そいでさあ、私さあ、その前の日におなかの調子が、胃の調子が悪くって、その冷たいサ...    ['前']
# 189     勝手に思って、すぐ止ま、だか、その前がちょんちょん止まってたもんで、すぐ止まると思ったんだ。    ['前']
# 199                      その前に、だからあたしはロイヤルドルトンでお昼を食べたの。    ['前']
# 129  そしたらＣとだんなさんが一緒に来てくれて、ね、でね、この日のね夜に、あたしはその前の日にチェ...    ['前']
# 8                                  すごい古いんだけど、こん中に。（おー）   ['こん']
#
#      concrete_score  use_word_num
# 186           255.5             1
# 264           255.5             1
# 119           255.5             1
# 51            257.0             1
# 210           258.0             1
# 146           258.0             1
# 189           258.0             1
# 199           258.0             1
# 129           258.0             1
# 8             259.5             1
